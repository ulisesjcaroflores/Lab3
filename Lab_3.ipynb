# %% [markdown]
# <a href="https://colab.research.google.com/github/ulisesjcaroflores/Lab3/blob/main/Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #### **First Dataset**

# %%
import pandas as pd
xmas = pd.read_csv("https://www.dropbox.com/scl/fi/qxaslqqp5p08i1650rpc4/xmas.csv?rlkey=erdxi7jbh7pqf9fh4lv4cayp5&dl=1")

# %%
xmas.head()
# Out:
#    Day Day.in.Words  Gift.Item Verb Adjective        Location
# 0    1        first  partridge  NaN       NaN  in a pear tree
# 1    2       second       dove  NaN    turtle             NaN
# 2    3        third        hen  NaN    french             NaN
# 3    4       fourth       bird  NaN   calling             NaN
# 4    5        fifth       ring  NaN    golden             NaN

# %% [markdown]
# #### **Practice making sing_day()**

# %%
def sing_day(day, day_in_words, gifts):

    if day < 1 or day > 12:
        return "Try again"

    verse = f"On the {day_in_words} day of Christmas, my true love gave to me:\n{gifts}"
    return verse

# %%
print(sing_day(1, "first", "A partridge in a pear tree"))
print(sing_day(2, "second", "Two turtle doves, and a partridge in a pear tree"))
# Out:
# On the first day of Christmas, my true love gave to me:
# A partridge in a pear tree
# On the second day of Christmas, my true love gave to me:
# Two turtle doves, and a partridge in a pear tree

# %% [markdown]
# #### **Pluralizing gift**

# %%
def pluralize_gift(gift):
    if isinstance(gift, pd.Series):
        return gift.apply(pluralize_gift)

    if gift == "goose":
        gift = "geese"
    elif len(gift) >= 2 and gift.endswith("y") and gift[-2].lower() not in "aeiou":
        gift = gift[:-1] + "ies"
    else:
        gift = gift + "s"

    return gift

# %% [markdown]
# ##### **TEST 1**

# %%
# Should work
pluralize_gift("goose")

# Will work if your function is vectorized!
pluralize_gift(xmas['Gift.Item'])
# Out:
# 0     partridges
# 1          doves
# 2           hens
# 3          birds
# 4          rings
# 5          geese
# 6          swans
# 7          maids
# 8         ladies
# 9          lords
# 10        pipers
# 11      drummers
# Name: Gift.Item, dtype: object

# %% [markdown]
# #### **Make_phrase function**

# %%
def make_phrase(num, num_word, item, verb, adjective, location):
  """
  <documentation here>
  """

  verb = "" if pd.isna(verb) else verb
  adjective = "" if pd.isna(adjective) else adjective
  location = "" if pd.isna(location) else location

  if num > 1 and item.lower() not in ['lords', 'ladies', 'pipers', 'drummers']:
      item = pluralize_gift(item)

  starts_vowel = False
  if isinstance(item, str) and len(item) > 0:
      starts_vowel = item.lower()[0] in 'aeiou'

  day_prefix = ""
  if num == 1:
      if starts_vowel:
          day_prefix = "an"
      else:
          day_prefix = "a"
  else:
      day_prefix = num_word

  adjective_part = f"{adjective} " if adjective else ""
  verb_part = f" {verb}" if verb else ""
  location_part = f" {location}" if location else ""

  if num == 1:
      phrase = f"{day_prefix} {item}{location_part}"
  else:
       phrase = f"{day_prefix} {adjective_part}{item}{verb_part}{location_part}".strip()


  return phrase

# %%
make_phrase(num = 10,
            num_word = "ten",
            item = "lords",
            verb = "a-leaping",
            adjective = "",
            location = "")
# Out:
# 'ten lords a-leaping'

# %%
pluralize_gift("cat")

make_phrase(num = 1,
            num_word= "first",
            item="cat",
            verb="",
            adjective="",
            location="in a pear tree")
# Out:
# 'a cat in a pear tree'

# %%
pluralize_gift("drummer")

make_phrase(num = 12,
            num_word= "twelve",
            item="drummer",
            verb="drumming",
            adjective="",
            location="")
# Out:
# 'twelve drummers drumming'

# %% [markdown]
# #### **Mapping Day.in.Word to the number spelt out**

# %%
xmas["write_day"] = xmas["Day.in.Words"].map({
    "first": "One",
    "second": "Two",
    "third": "Three",
    "fourth": "Four",
    "fifth": "Five",
    "sixth": "Six",
    "seventh": "Seven",
    "eighth": "Eight",
    "ninth": "Nine",
    "tenth": "Ten",
    "eleventh": "Eleven",
    "twelfth": "Twelve",
})
xmas.head()
# Out:
#    Day Day.in.Words  Gift.Item Verb Adjective        Location write_day
# 0    1        first  partridge  NaN       NaN  in a pear tree       One
# 1    2       second       dove  NaN    turtle             NaN       Two
# 2    3        third        hen  NaN    french             NaN     Three
# 3    4       fourth       bird  NaN   calling             NaN      Four
# 4    5        fifth       ring  NaN    golden             NaN      Five

# %%
xmas['Full.Phrase'] = xmas.apply(
    lambda row: make_phrase(
        num=row['Day'],
        num_word=row['write_day'],
        item=row['Gift.Item'],
        verb=row['Verb'],
        adjective=row['Adjective'],
        location=row['Location']
    ),
    axis=1
)

display(xmas)
# Out:
#     Day Day.in.Words  Gift.Item        Verb Adjective        Location  \
# 0     1        first  partridge         NaN       NaN  in a pear tree
# 1     2       second       dove         NaN    turtle             NaN
# 2     3        third        hen         NaN    french             NaN
# 3     4       fourth       bird         NaN   calling             NaN
# 4     5        fifth       ring         NaN    golden             NaN
# 5     6        sixth      goose    a-laying       NaN             NaN
# 6     7      seventh       swan  a-swimming       NaN             NaN
# 7     8       eighth       maid   a-milking       NaN             NaN
# 8     9        ninth       lady     dancing       NaN             NaN
# 9    10        tenth       lord   a-leaping       NaN             NaN
# 10   11     eleventh      piper      piping       NaN             NaN
# 11   12      twelfth    drummer    drumming       NaN             NaN
#
#    write_day                 Full.Phrase
# ...

# %% [markdown]
# #### **Creating the sing_day() bringing it all together**

# %%
def sing_day(dataset, num, phrase_col):
  """
  <documentation>
  """

  # Step 1: Setup the intro line
  # convert "1" to "first" etc.
  num_word = dataset.loc[num - 1, 'Day.in.Words']
  intro = "On the " + num_word + " day of Christmas, my true love sent to me: \n"

  # Step 2: Sing the gift phrases
  # Hint: What order are they gifts sung in each day?
  gifts = ""
  for i in range(num-1, -1, -1):
    gifts = gifts + dataset.loc[i, phrase_col]

    if i == 0:
            gifts = gifts + ".\n"
    else:
            gifts = gifts + ",\n"

    if num > 1:
        gifts = gifts.replace(dataset.loc[0, phrase_col],
                              "and " + dataset.loc[0, phrase_col], 1)


  # Step 3: Put it all together and return
  return intro + gifts

# %%
sing_day(xmas, 3, "Full.Phrase")
# Out:
# 'On the third day of Christmas, my true love sent to me: \nThree french hens,\nTwo turtle doves,\nand a partridge in a pear tree.\n'

# %%
print(sing_day(xmas, 3, "Full.Phrase"))
# Out:
# On the third day of Christmas, my true love sent to me:
# Three french hens,
# Two turtle doves,
# and a partridge in a pear tree.

# %%
complete_song_lyrics = print(sing_day(xmas, 12, "Full.Phrase"))
# Out:
# On the twelfth day of Christmas, my true love sent to me:
# Twelve drummers drumming,
# Eleven pipers piping,
# Ten lords a-leaping,
# Nine ladies dancing,
# Eight maids a-milking,
# Seven swans a-swimming,
# Six geese a-laying,
# Five golden rings,
# Four calling birds,
# Three french hens,
# Two turtle doves,
# and a partridge in a pear tree.

# %% [markdown]
# #### **Second dataset**

# %%
xmas2 = pd.read_csv("https://www.dropbox.com/scl/fi/p9x9k8xwuzs9rhp582vfy/xmas_2.csv?rlkey=kvc3j3lmyn4opcidsrhcmrof1&dl=1")

# %%
xmas2["write_day"] = xmas2["Day.in.Words"].map({
    "first": "One",
    "second": "Two",
    "third": "Three",
    "fourth": "Four",
    "fifth": "Five",
    "sixth": "Six",
    "seventh": "Seven",
    "eighth": "Eight",
    "ninth": "Nine",
    "tenth": "Ten",
    "eleventh": "Eleven",
    "twelfth": "Twelve",
})
display(xmas2)
# Out:
#     Day Day.in.Words Gift.Item         Verb Adjective       Location write_day
# 0     1        first     email          NaN       NaN  from Cal Poly       One
# 1     2       second     point          NaN      meal            NaN       Two
# 2     3        third       pen          NaN      lost            NaN     Three
# 3     4       fourth    review          NaN    course            NaN      Four
# 4     5        fifth      exam          NaN  practice            NaN      Five
# 5     6        sixth    grader      grading       NaN            NaN       Six
# 6     7      seventh    senior    stressing       NaN            NaN     Seven
# 7     8       eighth       mom    a-calling       NaN            NaN     Eight
# 8     9        ninth     party      bumping       NaN            NaN      Nine
# 9    10        tenth      load   of laundry       NaN            NaN       Ten
# 10   11     eleventh    friend  goodbye-ing       NaN            NaN    Eleven
# ...

# %%
xmas2['Full.Phrase'] = xmas2.apply(
    lambda row: make_phrase(
        num=row['Day'],
        num_word=row['write_day'],
        item=row['Gift.Item'],
        verb=row['Verb'],
        adjective=row['Adjective'],
        location=row['Location']
    ),
    axis=1
)

display(xmas2)
# Out:
#     Day Day.in.Words Gift.Item         Verb Adjective       Location  \
# 0     1        first     email          NaN       NaN  from Cal Poly
# 1     2       second     point          NaN      meal            NaN
# 2     3        third       pen          NaN      lost            NaN
# 3     4       fourth    review          NaN    course            NaN
# 4     5        fifth      exam          NaN  practice            NaN
# 5     6        sixth    grader      grading       NaN            NaN
# 6     7      seventh    senior    stressing       NaN            NaN
# 7     8       eighth       mom    a-calling       NaN            NaN
# 8     9        ninth     party      bumping       NaN            NaN
# 9    10        tenth      load   of laundry       NaN            NaN
# 10   11     eleventh    friend  goodbye-ing       NaN            NaN
# 11   12      twelfth      hour     sleeping       NaN            NaN
#
#    write_day                 Full.Phrase
# ...

# %%
complete_song_lyrics2 = print(sing_day(xmas2, 12, "Full.Phrase"))
# Out:
# On the twelfth day of Christmas, my true love sent to me:
# Twelve hours sleeping,
# Eleven friends goodbye-ing,
# Ten loads of laundry,
# Nine parties bumping,
# Eight moms a-calling,
# Seven seniors stressing,
# Six graders grading,
# Five practice exams,
# Four course reviews,
# Three lost pens,
# Two meal points,
# and an email from Cal Poly.
